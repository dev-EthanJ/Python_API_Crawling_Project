# %% [markdown]
# # 결론
#
# ### 서론에서 보여준 논문의 자료와 최근 시점의 분석결과를 토대로 비교 후 결과 도출

# %% [markdown]
# ![image.png](attachment:image.png)
#
# #### <논문결과>
# ##### 주택 매매가격지수는 여전히 전세가격과 동일한 방향이며 영향도 다른 변수보다 크다.
# ##### 그 이유는 한국의 주택은 높은 투자가치로서 인식되고있다.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# #### <논문결과>
# ##### 가계대출금리상승 또한 전세가격의 상승에 영향을 끼친다
#
# ##### 금리인상에 따른 대출 부담을 덜기 위해 집 팔고 전,월세 시장으로 옮긴다.
# ##### 주택 가격이 높을 수록 구입가격에 대출비중 높인다.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# #### <논문결과>
# ##### 시장이 불안하면 예금을 안정적으로 투자하고 싶어진다.
# ##### 주택거래가 정체되면 가격이 떨어질것을 염려해 소비를 줄이고 저축한다. 대신 일부 자금으로 전세로 입주

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# #### <논문결과>
# ##### 취업자 수의 증가는 총 인구에서 소득을 창출하는 인구비중의 증가를 의미한다.
# ##### 따라서 전 ,월세 제도를 통한 주택을 소비할 수 있는 사람이 많아짐을 뜻함

# %% [markdown]
# ### Project contributor: 나정민, 도형준, 유하영, 장인성
#
# - 나정민: "가계대출금리", "주택전세가격" data 수집, "결론" 작성
#
# - 도형준: "가계예금총액" data 수집, data visualizaion
#
# - 유하영: "주택매매가격" data 수집
#
# - 장인성: "경제활동인구" data 수집, "서론 및 목차" 작성

# %% [markdown]
# #### 자료 출처
#
# - 한국은행 Open API 서비스

# %% [markdown]
# # Thanks
# ##### 2022.10.27
